# %% [markdown]
# #  problem-statement
# https://leetcode.com/problems/merge-sorted-array/
#
# # solution
# 1. traverse nums1  and iterate over n elements only
# 2. remove n elements (pop)
# 3. extend nums1 to nums2
# 4. sort nums1 in non-decreasing order
#
# Note
# iteration over n elements in an 1D array with m+n elements
# for _ in range(n) # “Repeat this block n times.I do NOT care about the loop variable.”

# %%
nums1=[1,2,3,4,0,0,0]
nums2=[2,3,4]

print(nums1, nums2)
# Out:
# [1, 2, 3, 4, 0, 0, 0] [2, 3, 4]

# %%
nums1[-1]
# Out:
# 0

# %%
#accesing elements by  defining starting index , stopping index and step
m = len(nums1)
for i in range(m-1,-1,-1): #(start,end,step)
    print(i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
nums

# %%
#popping
nums1=[1,2,3,0,0,0]
nums2= [2,5,6]
m =3
n = 3
for _ in  range(n): #iterate n times irrespective of values
    nums1.pop()
nums1.extend(nums2)
print(nums1)
# Out:
# [1, 2, 3, 2, 5, 6]
