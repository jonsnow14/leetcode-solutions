# %%
# spiral matrix

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
t,b = 0,len(matrix)-1
l,r = 0, len(matrix[0])-1
(t,b),(l,r)
# Out:
# ((0, 2), (0, 2))

# %%
result = []

# %%
while t <=b and l <=r:
    for i in range(l, r+1):
        result.append(matrix[t][i])
        t +=1
print(result)
# Out:
# [1, 5, 9]

# %%
for i in range (t, b+1):
    result.append(matrix[i][r])
r-=1
print(result)
# Out:
# [1, 5, 9]

# %%
if t <=b:
    for i in range(r, l-1, -1):
      result.append(matrix[b][i])
    b -= 1
print(result)
# Out:
# [1, 5, 9]

# %%
if l<=r:
    for i in range(b,t-1,-1):
        result.append(matrix[i][l])
    l += 1
print(result)
# Out:
# [1, 5, 9]

# %%
class Solution:
    def spiralOrder(self,matrix):

        result = []
        t,b = 0,len(matrix)-1
        l,r = 0, len(matrix[0])-1
        while t <=b and l <=r:
            for i in range(l, r+1):
                result.append(matrix[t][i])
            t +=1

            for i in range (t, b+1):
                result.append(matrix[i][r])
            r-=1

            if t <=b:
                for i in range(r, l-1, -1):
                  result.append(matrix[b][i])
                b -= 1

            if l<=r:
                for i in range(b,t-1,-1):
                    result.append(matrix[i][l])
                l += 1
        return result

self = Solution()
matrix = [[1,2,3],[4,5,6],[7,8,9]]
SPIRAL_MATRIX = self.spiralOrder(matrix)
print(SPIRAL_MATRIX)
# Out:
# [1, 2, 3, 6, 9, 8, 7, 4, 5]

# %%
# Out:
# None
